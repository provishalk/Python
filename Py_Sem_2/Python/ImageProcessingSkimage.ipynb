# %%
# 1 Reading Images in Python using skimage
# Loading Images from skimage
from skimage.io import imread, imshow
from skimage import data
image = data.astronaut()
imshow(image)

# %%
# Reading Images from our System using skimage
from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# %matplotlib inline

image_gray = imread('pp.jpg', as_gray=True)
imshow(image_gray)

# %%
print(image_gray.shape)
print(image_gray)
# Out:
# (520, 520)
# [[0.19388314 0.19388314 0.19388314 ... 0.19860824 0.19860824 0.19468667]
#  [0.19388314 0.19388314 0.19388314 ... 0.19860824 0.19860824 0.19468667]
#  [0.19388314 0.19388314 0.19388314 ... 0.19860824 0.19860824 0.19468667]
#  ...
#  [0.16136471 0.15352157 0.14175686 ... 0.10056902 0.09272588 0.08488275]
#  [0.15744314 0.16136471 0.15744314 ... 0.10056902 0.09272588 0.08488275]
#  [0.15352157 0.16528627 0.16920784 ... 0.10056902 0.08880431 0.08488275]]

# %%
# image in RGB, 3 channel

from skimage.io import imread, imshow
import matplotlib.pyplot as plt
# %matplotlib inline

image_color = imread('pp.jpg', as_gray=False)
print(image_color.shape)
imshow(image_color)
# Out:
# (520, 520, 3)

# %%
# 2. Changing Image Format

from skimage.color import rgb2gray
img = imread('pp.jpg')
img_new = rgb2gray(img)

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('Grayscale Format') 

plt.show()

# %%
# RGB to HSL, HSV

from skimage.color import rgb2hsv
img = imread('pp.jpg')
img_new = rgb2hsv(img)

plt.subplot(121), imshow(img)
plt.title('RGB Format') 

plt.subplot(122), imshow(img_new)
plt.title('HSV Format') 

plt.show()

# %%
# 3. Resizing Images using skimage

from skimage.transform import resize
img = imread('pp.jpg')
#resize image
img_resized = resize(img, (300, 300))

#plot images
plt.subplot(121), imshow(img)
plt.title('Original Image')
plt.subplot(122), imshow(img_resized)
plt.title('Resized Image')
plt.show()

# %%
# 4. Rescaling (Upscale/Downscale) Images using skimage

from skimage.transform import rescale
img = imread('pp.jpg')
img_rescaled = rescale(img, scale=(0.5,0.5))


plt.subplot(121), imshow(img)
plt.title('Original Image')

plt.subplot(122), imshow(img_rescaled)
plt.title('Rescaled Image')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-1d3f01e083fb> in <module>
#       3 from skimage.transform import rescale
#       4 img = imread('pp.jpg')
# ----> 5 img_rescaled = rescale(img, scale=(0.5,0.5))
#       6
#       7
#
# ~\anaconda3\lib\site-packages\skimage\transform\_warps.py in rescale(image, scale, order, mode, cval, clip, preserve_range, multichannel, anti_aliasing, anti_aliasing_sigma)
#     279         if ((not multichannel and len(scale) != image.ndim) or
#     280                 (multichannel and len(scale) != image.ndim - 1)):
# --> 281             raise ValueError("Supply a single scale, or one value per spatial "
#     282                              "axis")
#     283         if multichannel:
#
# ValueError: Supply a single scale, or one value per spatial axis

# %%
# 5. Rotate an Image by Different Angles using skimage

from skimage.transform import rotate
image = imread('pp.jpg')

image_rotated = rotate(image, angle=45)
imshow(image_rotated)

# %%
# Rotation with out cropping

from skimage.transform import rotate
image = imread('pp.jpg')

image_rotated = rotate(image, angle=45, resize=True)
imshow(image_rotated)

# %%
# 6. Flip Images Horizontally and Vertically

from numpy import fliplr, flipud
dog = imread('puppy.jpg')
cat = imread('whiskers.jpg')

dog_flip = fliplr(dog)
cat_flip = fliplr(cat)

plt.subplot(141), imshow(dog)
plt.subplot(142), imshow(dog_flip)
plt.subplot(143), imshow(cat)
plt.subplot(144), imshow(cat_flip)
plt.show()

# %%
# 7. Crop Images

image = imread('warriors.jpg')

# selecting part of the image only 
cropped = image[100:(img.shape[0]-100),100:(img.shape[1]-100)]

plt.subplot(121), imshow(image)
plt.title('Original Image')
plt.subplot(122),imshow(cropped)
plt.title('Cropped Image')

plt.show()

# %%
# 8. Altering Image Brightness using skimage
# gamma correlation


from skimage import exposure

#adjusting brightness
image = imread('warriors.jpg')
image_bright = exposure.adjust_gamma(image, gamma=0.5,gain=1)
image_dark = exposure.adjust_gamma(image, gamma=1.5,gain=1)

# plotting images
plt.subplot(131), imshow(image)
plt.title('Original Image')

plt.subplot(132),imshow(image_bright)
plt.title('Bright Image')

plt.subplot(133),imshow(image_dark)
plt.title('Dark Image')

plt.show()

# %%
# 9. Using Filters in skimage

from skimage.filters import median

image = imread('warriors.jpg', as_gray=True)
image_median = median(image)

# plotting images
plt.subplot(121), imshow(image)
plt.title('Original Image')

plt.subplot(122),imshow(image_median)
plt.title('Smooth Image')

plt.show()

# %%
# temp

from skimage.filters import sobel_h

image = imread('warriors.jpg', as_gray=True)
imshow(image)

image_sobelh = sobel_h(image)

# plotting images
plt.subplot(121), imshow(image)
plt.title('Original Image')

plt.subplot(122),imshow(image_sobelh, cmap = True)
plt.title('Horizontal Edge')

plt.show()
